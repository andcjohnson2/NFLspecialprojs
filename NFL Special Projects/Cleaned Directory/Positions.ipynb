# %%
# %run Decoder.ipynb

# %%
## This function will let us know if someone is lined up over center
def over_center(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        
        if x<=item[1]<=y:
            return True
    return False




def left_a_gap(arg1, arg2, arg3,x,y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False


def over_left_guard(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False



def left_three_technique(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False


def over_left_tackle(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    print(arg)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False


## This will tell us if we have a rusher on the right side also based on the position of the TEs
def left_edge_rusher(arg1, arg2, arg3, te_location):
    tes = tight_ends_number_and_location(te_location)
    d_line = defensive_locations(arg1, arg2, arg3)
    i = 0
    num_r_te = tes[1]
    
    if num_r_te == 0:
        for item in d_line:
            if item[1]<=13:
                i+=1
    elif num_r_te ==1:
        for item in d_line:
            if item[1]<=9:
                i+=1
    elif num_r_te ==2:
        for item in d_line:
            if item[1]<=5:
                i+=1
    elif num_r_te ==3:
        for item in d_line:
            if item[1]<=1:
                i+=1
    else:
        print("too many TE's")
    
    if i==1:
        return True
    else: 
        return False


def right_a_gap(arg1, arg2, arg3,x,y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False

            
def over_right_guard(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False


def right_three_technique(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False


def over_right_tackle(arg1, arg2, arg3, x, y):
    arg = defensive_locations(arg1, arg2, arg3)
    for item in arg:
        if x<=item[1]<=y:
            return True
    return False

def right_edge_rusher(arg1, arg2, arg3, te_location):
    tes = tight_ends_number_and_location(te_location)
    d_line = defensive_locations(arg1, arg2, arg3)
    i = 0
    num_l_te = tes[0]
    if num_l_te == 0:
        for item in d_line:
            if item[1]>=31:
                i+=1
    elif num_l_te ==1:
        for item in d_line:
            if item[1]>=35:
                i+=1
    elif num_l_te ==2:
        for item in d_line:
            if item[1]>=39:
                i+=1
    elif num_l_te ==3:
        for item in d_line:
            if item[1]>=43:
                i+=1
    else:
        print("too many TE's")
    
    if i==1:
        return True
    else: 
        return False
    
## This will tell us if we have a rusher on the right side also based on the position of the TEs
def count_left_edge_rusher(arg1, arg2, arg3, te_location):
    tes = tight_ends_number_and_location(te_location)
    d_line = defensive_locations(arg1, arg2, arg3)
    i = 0
    num_r_te = tes[1]
    if num_r_te == 0:
        for item in d_line:
            if item[1]<=13:
                i+=1
    elif num_r_te ==1:
        for item in d_line:
            if item[1]<=9:
                i+=1
    elif num_r_te ==2:
        for item in d_line:
            if item[1]<=5:
                i+=1
    elif num_r_te ==3:
        for item in d_line:
            if item[1]<=1:
                i+=1
    else:
        print("too many TE's")
    
    return i

## This will tell us if there is a rusher on the left side based on the positioning of the TEs
def count_right_edge_rusher(arg1, arg2, arg3, te_location):
    tes = tight_ends_number_and_location(te_location)
    d_line = defensive_locations(arg1, arg2, arg3)
    
    i = 0
    num_l_te = tes[0]
    
    if num_l_te == 0:
        for item in d_line:
            if item[1]>=31:
                i+=1
    elif num_l_te ==1:
        for item in d_line:
            if item[1]>=35:
                i+=1
    elif num_l_te ==2:
        for item in d_line:
            if item[1]>=39:
                i+=1
    elif num_l_te ==3:
        for item in d_line:
            if item[1]>=43:
                i+=1
    else:
        print("too many TE's")
    
    return i
